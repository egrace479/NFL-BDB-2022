# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")

# %% [markdown]
# Note we have 7 files from the competetition hosts:
# - Game Data: games.csv, the data for each game (season, date & time, location, home and visitor teams), key variable is `gameID`.
# - PFF Scouting Data: PFFScoutingData.csv, "play-level scouting information for each game", key variables are `gameID` and `playID` (note `nflID` not included). Information about kick types, directions, and air time throughout the game.
# - Player Data: players.csv, information for each player (height, weight, birth, college, position, name), key variable is `nflID` (Does not include `gameID` and `playID`).
# - Play Data: plays.csv, "play-level information from each game", key variables are `gameID` and `playID`. Game-specific temporal information, type of play and play result. `kickerId` is `nflId` of kicker.
# - Tracking Data: tracking2018.csv, tracking 2019.csv, and tracking2020.csv. Each contains "player tracking data" from the indicated season, key variables are `gameID`, `nflID`, and `playID`. Each player's position on the field as well as the football for all special teams plays per game.
# We also have a weather dataset from ThomasJBliss.

# %%
games = pd.read_csv("/Users/Edmonds.110/Desktop/Python/EI/nfl-big-data-bowl-2022/games.csv")

scout = pd.read_csv("/Users/Edmonds.110/Desktop/Python/EI/nfl-big-data-bowl-2022/PFFScoutingData.csv")

players = pd.read_csv("/Users/Edmonds.110/Desktop/Python/EI/nfl-big-data-bowl-2022/players.csv")

play = pd.read_csv("/Users/Edmonds.110/Desktop/Python/EI/nfl-big-data-bowl-2022/plays.csv")

track18 = pd.read_csv("/Users/Edmonds.110/Desktop/Python/EI/nfl-big-data-bowl-2022/tracking2018.csv")
track19 = pd.read_csv("/Users/Edmonds.110/Desktop/Python/EI/nfl-big-data-bowl-2022/tracking2019.csv")
track20 = pd.read_csv("/Users/Edmonds.110/Desktop/Python/EI/nfl-big-data-bowl-2022/tracking2020.csv")

g_weather = pd.read_csv("/Users/Edmonds.110/Desktop/Python/EI/nfl-big-data-bowl-2022/games_weather.csv")
game_ident = pd.read_csv("/Users/Edmonds.110/Desktop/Python/EI/nfl-big-data-bowl-2022/games_w.csv")
stadium_ident = pd.read_csv("/Users/Edmonds.110/Desktop/Python/EI/nfl-big-data-bowl-2022/stadium_coordinates.csv")

# %% [markdown]
# Weather data needs to be combined into three datasets, one per year.

# %%
def get_weather_data():
    # Pull down datasets
    
    # Merge game and weather data on game_id
    g_weather_merge = pd.merge(g_weather, game_ident, on='game_id')

    # Merge stadium data on StadiumName
    final_df = pd.merge(g_weather_merge, stadium_ident, on='StadiumName')

    # Convert time columns to datetime objects
    time_cols = ['TimeMeasure', 'TimeStartGame', 'TimeEndGame']

    for col in time_cols:
        final_df[col] = pd.to_datetime(final_df[col], format='%m/%d/%Y %H:%M')

    # Create sliced DataFrames
    weather2018 = final_df[final_df['TimeMeasure'].dt.year == 2018]
    weather2019 = final_df[final_df['TimeMeasure'].dt.year == 2019]
    weather2020 = final_df[final_df['TimeMeasure'].dt.year == 2020]

    return weather2018, weather2019, weather2020

# %%
weather2018, weather2019, weather2020 = get_weather_data()

# %%
weather2018
# Out:
#           game_id     Source  DistanceToStation         TimeMeasure  \
# 3099   2018091608  Meteostat               3.98 2018-09-16 12:00:00
# 3100   2018091608  Meteostat               3.98 2018-09-16 13:00:00
# 3101   2018091608  Meteostat               3.98 2018-09-16 14:00:00
# 3102   2018091608  Meteostat               3.98 2018-09-16 15:00:00
# 3103   2018091608  Meteostat               3.98 2018-09-16 16:00:00
# ...           ...        ...                ...                 ...
# 39067  2018121600  Meteostat               4.47 2018-12-16 14:00:00
# 39068  2018121600  Meteostat               4.47 2018-12-16 15:00:00
# 39069  2018121600  Meteostat               4.47 2018-12-16 16:00:00
# 39070  2018121600  Meteostat               4.47 2018-12-16 17:00:00
# 39071  2018121600  Meteostat               4.47 2018-12-16 18:00:00
#
#        Temperature  DewPoint  Humidity  Precipitation  WindSpeed  \
# 3099         75.56     68.90      80.0            0.0      10.31
# 3100         75.92     68.54      78.0            0.0       8.08
# 3101         77.72     69.62      76.0            0.0       9.20
# 3102         78.80     69.44      73.0            0.0       9.20
# 3103         80.24     69.62      70.0            0.0      12.74
# ...            ...       ...       ...            ...        ...
# 39067        51.98     46.94      83.0            0.0       6.96
# 39068        53.06     44.96      74.0            0.0       5.84
# 39069        53.06     46.04      77.0            0.0       9.20
# 39070        53.06     46.04      77.0            0.0      14.98
# 39071        51.98     44.96      77.0            0.0      10.31
#
#        WindDirection  ...  Season            StadiumName       TimeStartGame  \
# 3099            90.0  ...    2018             FedExField 2018-09-16 13:00:00
# 3100            40.0  ...    2018             FedExField 2018-09-16 13:00:00
# 3101            30.0  ...    2018             FedExField 2018-09-16 13:00:00
# 3102            70.0  ...    2018             FedExField 2018-09-16 13:00:00
# 3103           100.0  ...    2018             FedExField 2018-09-16 13:00:00
# ...              ...  ...     ...                    ...                 ...
# 39067          310.0  ...    2018  Mercedes-Benz Stadium 2018-12-16 13:00:00
# 39068          310.0  ...    2018  Mercedes-Benz Stadium 2018-12-16 13:00:00
# 39069          310.0  ...    2018  Mercedes-Benz Stadium 2018-12-16 13:00:00
# 39070          310.0  ...    2018  Mercedes-Benz Stadium 2018-12-16 13:00:00
# 39071          340.0  ...    2018  Mercedes-Benz Stadium 2018-12-16 13:00:00
#
#               TimeEndGame TZOffset HomeTeam     RoofType  Longitude  \
# 3099  2018-09-16 15:53:00       -4      WAS      Outdoor -76.864444
# 3100  2018-09-16 15:53:00       -4      WAS      Outdoor -76.864444
# 3101  2018-09-16 15:53:00       -4      WAS      Outdoor -76.864444
# 3102  2018-09-16 15:53:00       -4      WAS      Outdoor -76.864444
# 3103  2018-09-16 15:53:00       -4      WAS      Outdoor -76.864444
# ...                   ...      ...      ...          ...        ...
# 39067 2018-12-16 16:07:00       -5      ATL  Retractable -84.400000
# 39068 2018-12-16 16:07:00       -5      ATL  Retractable -84.400000
# 39069 2018-12-16 16:07:00       -5      ATL  Retractable -84.400000
# 39070 2018-12-16 16:07:00       -5      ATL  Retractable -84.400000
# 39071 2018-12-16 16:07:00       -5      ATL  Retractable -84.400000
#
#         Latitude  StadiumAzimuthAngle
# 3099   38.907778                295.0
# 3100   38.907778                295.0
# 3101   38.907778                295.0
# 3102   38.907778                295.0
# 3103   38.907778                295.0
# ...          ...                  ...
# 39067  33.755556                 70.9
# 39068  33.755556                 70.9
# 39069  33.755556                 70.9
# 39070  33.755556                 70.9
# 39071  33.755556                 70.9
#
# [2166 rows x 22 columns]

# %% [markdown]
# We need to standardize the height of all players. Inches will be easier to code with, so we first define a function `ft_in` to convert all heights from ft-in to inches. It also takes inches to an `int`. Then we will apply it to the `height` column of our dataframe.

# %%
def ft_in(x):
    if '-' in x:
        meas=x.split('-')
        #this will be a list ['ft','in']
        inches = int(meas[0])*12 + int(meas[1])
        return inches
    else:
        return int(x)

# %%
players['height'] = players['height'].apply(ft_in)

# %% [markdown]
# Now, we turn to the tracking data. We must reorient this to reflect movement in the offense direction instead of the on-field coordinates (reorient the orgin from the bottom left to top right for a change in direction).

# %%
#2018 tracking data
track18.loc[track18['playDirection'] == 'left', 'x'] = 120 -track18.loc[track18['playDirection']=='left','x']
track18.loc[track18['playDirection'] == 'left', 'y'] = 160/3 -track18.loc[track18['playDirection']=='left','y']
#note that we have 160/3 for the y direction since the football field is 160ft, but our units are yards

#2019 tracking data
track19.loc[track19['playDirection'] == 'left', 'x'] = 120 -track19.loc[track19['playDirection']=='left','x']
track19.loc[track19['playDirection'] == 'left', 'y'] = 160/3 -track19.loc[track19['playDirection']=='left','y']

#2020 tracking data
track20.loc[track20['playDirection'] == 'left', 'x'] = 120 -track20.loc[track20['playDirection']=='left','x']
track20.loc[track20['playDirection'] == 'left', 'y'] = 160/3 -track20.loc[track20['playDirection']=='left','y']

# %% [markdown]
# We are specifically looking at `Extra Point` in this Notebook. So we pull just that play data.

# %%
#extraPoint
play_extrapoint = play.loc[play['specialTeamsPlayType']=='Extra Point']

# %%
play_extrapoint.value_counts('specialTeamsResult')
# Out:
# specialTeamsResult
# Kick Attempt Good           3252
# Kick Attempt No Good         199
# Blocked Kick Attempt          24
# Non-Special Teams Result      13
# dtype: int64

# %%
play_extrapoint.value_counts('kickReturnYardage')
# Out:
# Series([], dtype: int64)

# %%
play_extrapoint.value_counts('passResult')
# Out:
# passResult
# I    4
# dtype: int64

# %% [markdown]
# 4 of our Non-Special Teams Resutls are incomplete passes.

# %%
play_extrapoint.value_counts('yardlineNumber')
# Out:
# yardlineNumber
# 15    3438
# 20      29
# 10       8
# 25       6
# 30       5
# 7        2
# dtype: int64

# %%
play_extrapoint.value_counts('penaltyYards')
# Out:
# penaltyYards
#  15.0    31
#  5.0     28
# -15.0     3
#  0.0      3
# dtype: int64

# %%
play_extrapoint[play_extrapoint['penaltyYards']==0]
# Out:
#            gameId  playId                                    playDescription  \
# 3751   2018111104    1392  J.Lambo extra point is Blocked (D.Autry), Cent...
# 15764  2020102500    4362  M.Prater extra point is GOOD, Center-D.Muhlbac...
# 16406  2020110112    4733  B.McManus extra point is GOOD, Center-J.Bobenm...
#
#        quarter  down  yardsToGo possessionTeam specialTeamsPlayType  \
# 3751         2     0          0            JAX          Extra Point
# 15764        4     0          0            DET          Extra Point
# 16406        4     0          0            DEN          Extra Point
#
#          specialTeamsResult  kickerId  ... penaltyCodes  penaltyJerseyNumbers  \
# 3751   Blocked Kick Attempt   43068.0  ...          LBL                IND 36
# 15764     Kick Attempt Good   31446.0  ...          ILF                   ATL
# 16406     Kick Attempt Good   40276.0  ...          ILF                   LAC
#
#       penaltyYards  preSnapHomeScore preSnapVisitorScore passResult  \
# 3751           0.0                21                  13        NaN
# 15764          0.0                22                  22        NaN
# 16406          0.0                30                  30        NaN
#
#       kickLength  kickReturnYardage  playResult  absoluteYardlineNumber
# 3751         NaN                NaN           0                      95
# 15764        NaN                NaN           0                      40
# 16406        NaN                NaN           0                      25
#
# [3 rows x 25 columns]

# %% [markdown]
# 'LBL' = low block and 'ILF' = illegal formation

# %%
play_extrapoint[(play_extrapoint['penaltyCodes']=='LBL') | (play_extrapoint['penaltyCodes']=='ILF')]
# Out:
#            gameId  playId                                    playDescription  \
# 1543   2018093009    3479  M.McCrane extra point is GOOD, Center-T.Sieg, ...
# 2686   2018102106    1236  J.Sanders extra point is GOOD, Center-J.Denney...
# 3751   2018111104    1392  J.Lambo extra point is Blocked (D.Autry), Cent...
# 5252   2018120902     991  C.Catanzaro extra point is GOOD, Center-J.Jans...
# 15764  2020102500    4362  M.Prater extra point is GOOD, Center-D.Muhlbac...
# 16406  2020110112    4733  B.McManus extra point is GOOD, Center-J.Bobenm...
# 18922  2020122006    3769  A.Rosas extra point is GOOD, Center-R.Matiscik...
# 19889  2021010312    3758  S.Sloman extra point is GOOD, Center-M.Overton...
#
#        quarter  down  yardsToGo possessionTeam specialTeamsPlayType  \
# 1543         4     0          0            OAK          Extra Point
# 2686         2     0          0            MIA          Extra Point
# 3751         2     0          0            JAX          Extra Point
# 5252         2     0          0            CAR          Extra Point
# 15764        4     0          0            DET          Extra Point
# 16406        4     0          0            DEN          Extra Point
# 18922        4     0          0            JAX          Extra Point
# 19889        4     0          0            TEN          Extra Point
#
#          specialTeamsResult  kickerId  ... penaltyCodes  penaltyJerseyNumbers  \
# 1543      Kick Attempt Good   46663.0  ...          ILF                CLE 65
# 2686      Kick Attempt Good   46298.0  ...          ILF                DET 91
# 3751   Blocked Kick Attempt   43068.0  ...          LBL                IND 36
# 5252      Kick Attempt Good   41736.0  ...          ILF                CLE 90
# 15764     Kick Attempt Good   31446.0  ...          ILF                   ATL
# 16406     Kick Attempt Good   40276.0  ...          ILF                   LAC
# 18922     Kick Attempt Good   43937.0  ...          ILF                BAL 98
# 19889     Kick Attempt Good   52656.0  ...          ILF                   HOU
#
#       penaltyYards  preSnapHomeScore preSnapVisitorScore passResult  \
# 1543           5.0                30                  28        NaN
# 2686           5.0                 6                  10        NaN
# 3751           0.0                21                  13        NaN
# 5252           5.0                 7                  13        NaN
# 15764          0.0                22                  22        NaN
# 16406          0.0                30                  30        NaN
# 18922          5.0                40                  13        NaN
# 19889          5.0                35                  37        NaN
#
#       kickLength  kickReturnYardage  playResult  absoluteYardlineNumber
# 1543         NaN                NaN           0                      25
# 2686         NaN                NaN           0                      25
# 3751         NaN                NaN           0                      95
# 5252         NaN                NaN           0                      95
# 15764        NaN                NaN           0                      40
# 16406        NaN                NaN           0                      25
# 18922        NaN                NaN           0                      95
# 19889        NaN                NaN           0                      25
#
# [8 rows x 25 columns]

# %% [markdown]
# Remove columns that have no values or set values, i.e., `kickReturnYardage` is null and `yardsToGo` is always `0`.
#
# Note that `playDescription` should never be included in analysis, just good for reference later.

# %%
ep = play_extrapoint.drop(columns =['kickReturnYardage', 'kickLength', 'playResult', 'returnerId', 'yardsToGo', 'down', 'specialTeamsPlayType'])

# %%
ep
# Out:
#            gameId  playId                                    playDescription  \
# 15     2018090600    2883  J.Elliott extra point is GOOD, Center-R.Lovato...
# 19     2018090600    3553  M.Bryant extra point is No Good, Hit Right Upr...
# 25     2018090900     380  J.Tucker extra point is GOOD, Center-M.Cox, Ho...
# 30     2018090900     972  J.Tucker extra point is GOOD, Center-M.Cox, Ho...
# 44     2018090900    2757  J.Tucker extra point is GOOD, Center-M.Cox, Ho...
# ...           ...     ...                                                ...
# 19968  2021010315    2813  T.Vizcaino extra point is GOOD, Center-C.Holba...
# 19970  2021010315    3074  J.Myers extra point is No Good, Wide Left, Cen...
# 19973  2021010315    3667  J.Myers extra point is GOOD, Center-T.Ott, Hol...
# 19975  2021010315    3870  J.Myers extra point is GOOD, Center-T.Ott, Hol...
# 19977  2021010315    4166  T.Vizcaino extra point is GOOD, Center-C.Holba...
#
#        quarter possessionTeam    specialTeamsResult  kickerId  kickBlockerId  \
# 15           3            PHI     Kick Attempt Good   44966.0            NaN
# 19           4            ATL  Kick Attempt No Good   27091.0            NaN
# 25           1            BAL     Kick Attempt Good   39470.0            NaN
# 30           1            BAL     Kick Attempt Good   39470.0            NaN
# 44           3            BAL     Kick Attempt Good   39470.0            NaN
# ...        ...            ...                   ...       ...            ...
# 19968        4             SF     Kick Attempt Good   47590.0            NaN
# 19970        4            SEA  Kick Attempt No Good   41175.0            NaN
# 19973        4            SEA     Kick Attempt Good   41175.0            NaN
# 19975        4            SEA     Kick Attempt Good   41175.0            NaN
# 19977        4             SF     Kick Attempt Good   47590.0            NaN
#
#       yardlineSide  yardlineNumber gameClock penaltyCodes  \
# 15             ATL              15  04:37:00          NaN
# 19             PHI              15  09:48:00          NaN
# 25             BUF              15  08:42:00          NaN
# 30             BUF              15  01:32:00          NaN
# 44             BUF              15  12:28:00          NaN
# ...            ...             ...       ...          ...
# 19968          SEA              15  14:22:00          NaN
# 19970           SF              15  10:54:00          NaN
# 19973           SF              15  02:20:00          NaN
# 19975           SF              15  01:49:00          NaN
# 19977          SEA              15  00:23:00          NaN
#
#       penaltyJerseyNumbers  penaltyYards  preSnapHomeScore  \
# 15                     NaN           NaN                 9
# 19                     NaN           NaN                10
# 25                     NaN           NaN                 6
# 30                     NaN           NaN                13
# 44                     NaN           NaN                32
# ...                    ...           ...               ...
# 19968                  NaN           NaN                15
# 19970                  NaN           NaN                16
# 19973                  NaN           NaN                16
# 19975                  NaN           NaN                16
# 19977                  NaN           NaN                22
#
#        preSnapVisitorScore passResult  absoluteYardlineNumber
# 15                       6        NaN                      25
# 19                      12        NaN                      25
# 25                       0        NaN                      95
# 30                       0        NaN                      95
# 44                       0        NaN                      25
# ...                    ...        ...                     ...
# 19968                    6        NaN                      95
# 19970                   12        NaN                      25
# 19973                   18        NaN                      25
# 19975                   25        NaN                      25
# 19977                   26        NaN                      95
#
# [3488 rows x 18 columns]

# %%
ep_play = pd.merge(ep, players[['nflId', 'height', 'weight','Position', 'displayName']], how = 'left',
             left_on = 'kickerId', right_on = 'nflId', suffixes = (False,'_kicker'))
ep_play
# Out:
#           gameId  playId                                    playDescription  \
# 0     2018090600    2883  J.Elliott extra point is GOOD, Center-R.Lovato...
# 1     2018090600    3553  M.Bryant extra point is No Good, Hit Right Upr...
# 2     2018090900     380  J.Tucker extra point is GOOD, Center-M.Cox, Ho...
# 3     2018090900     972  J.Tucker extra point is GOOD, Center-M.Cox, Ho...
# 4     2018090900    2757  J.Tucker extra point is GOOD, Center-M.Cox, Ho...
# ...          ...     ...                                                ...
# 3483  2021010315    2813  T.Vizcaino extra point is GOOD, Center-C.Holba...
# 3484  2021010315    3074  J.Myers extra point is No Good, Wide Left, Cen...
# 3485  2021010315    3667  J.Myers extra point is GOOD, Center-T.Ott, Hol...
# 3486  2021010315    3870  J.Myers extra point is GOOD, Center-T.Ott, Hol...
# 3487  2021010315    4166  T.Vizcaino extra point is GOOD, Center-C.Holba...
#
#       quarter possessionTeam    specialTeamsResult  kickerId  kickBlockerId  \
# 0           3            PHI     Kick Attempt Good   44966.0            NaN
# 1           4            ATL  Kick Attempt No Good   27091.0            NaN
# 2           1            BAL     Kick Attempt Good   39470.0            NaN
# 3           1            BAL     Kick Attempt Good   39470.0            NaN
# 4           3            BAL     Kick Attempt Good   39470.0            NaN
# ...       ...            ...                   ...       ...            ...
# 3483        4             SF     Kick Attempt Good   47590.0            NaN
# 3484        4            SEA  Kick Attempt No Good   41175.0            NaN
# 3485        4            SEA     Kick Attempt Good   41175.0            NaN
# 3486        4            SEA     Kick Attempt Good   41175.0            NaN
# 3487        4             SF     Kick Attempt Good   47590.0            NaN
#
#      yardlineSide  yardlineNumber  ... penaltyYards preSnapHomeScore  \
# 0             ATL              15  ...          NaN                9
# 1             PHI              15  ...          NaN               10
# 2             BUF              15  ...          NaN                6
# 3             BUF              15  ...          NaN               13
# 4             BUF              15  ...          NaN               32
# ...           ...             ...  ...          ...              ...
# 3483          SEA              15  ...          NaN               15
# 3484           SF              15  ...          NaN               16
# 3485           SF              15  ...          NaN               16
# 3486           SF              15  ...          NaN               16
# 3487          SEA              15  ...          NaN               22
#
#      preSnapVisitorScore  passResult  absoluteYardlineNumber    nflId height  \
# 0                      6         NaN                      25  44966.0   69.0
# 1                     12         NaN                      25  27091.0   69.0
# 2                      0         NaN                      95  39470.0   73.0
# 3                      0         NaN                      95  39470.0   73.0
# 4                      0         NaN                      25  39470.0   73.0
# ...                  ...         ...                     ...      ...    ...
# 3483                   6         NaN                      95  47590.0   74.0
# 3484                  12         NaN                      25  41175.0   70.0
# 3485                  18         NaN                      25  41175.0   70.0
# 3486                  25         NaN                      25  41175.0   70.0
# 3487                  26         NaN                      95  47590.0   74.0
#
#       weight  Position       displayName
# 0      167.0         K      Jake Elliott
# 1      203.0         K       Matt Bryant
# 2      183.0         K     Justin Tucker
# 3      183.0         K     Justin Tucker
# 4      183.0         K     Justin Tucker
# ...      ...       ...               ...
# 3483   205.0         K  Tristan Vizcaino
# 3484   190.0         K       Jason Myers
# 3485   190.0         K       Jason Myers
# 3486   190.0         K       Jason Myers
# 3487   205.0         K  Tristan Vizcaino
#
# [3488 rows x 23 columns]

# %%
ep_play.value_counts('Position')
# Out:
# Position
# K    3466
# P       9
# dtype: int64

# %% [markdown]
# Rename player information to indicate kicker, then drop duplicate `nflId`.

# %%
ep_plays=ep_play.rename(columns = {"height": 'kicker_height', "weight": 'kicker_weight', "Position": 'kicker_position', "displayName": 'kicker_name'})

ep_plays=ep_plays.drop(columns=['nflId'])

# %%
ep_plays
# Out:
#           gameId  playId                                    playDescription  \
# 0     2018090600    2883  J.Elliott extra point is GOOD, Center-R.Lovato...
# 1     2018090600    3553  M.Bryant extra point is No Good, Hit Right Upr...
# 2     2018090900     380  J.Tucker extra point is GOOD, Center-M.Cox, Ho...
# 3     2018090900     972  J.Tucker extra point is GOOD, Center-M.Cox, Ho...
# 4     2018090900    2757  J.Tucker extra point is GOOD, Center-M.Cox, Ho...
# ...          ...     ...                                                ...
# 3483  2021010315    2813  T.Vizcaino extra point is GOOD, Center-C.Holba...
# 3484  2021010315    3074  J.Myers extra point is No Good, Wide Left, Cen...
# 3485  2021010315    3667  J.Myers extra point is GOOD, Center-T.Ott, Hol...
# 3486  2021010315    3870  J.Myers extra point is GOOD, Center-T.Ott, Hol...
# 3487  2021010315    4166  T.Vizcaino extra point is GOOD, Center-C.Holba...
#
#       quarter possessionTeam    specialTeamsResult  kickerId  kickBlockerId  \
# 0           3            PHI     Kick Attempt Good   44966.0            NaN
# 1           4            ATL  Kick Attempt No Good   27091.0            NaN
# 2           1            BAL     Kick Attempt Good   39470.0            NaN
# 3           1            BAL     Kick Attempt Good   39470.0            NaN
# 4           3            BAL     Kick Attempt Good   39470.0            NaN
# ...       ...            ...                   ...       ...            ...
# 3483        4             SF     Kick Attempt Good   47590.0            NaN
# 3484        4            SEA  Kick Attempt No Good   41175.0            NaN
# 3485        4            SEA     Kick Attempt Good   41175.0            NaN
# 3486        4            SEA     Kick Attempt Good   41175.0            NaN
# 3487        4             SF     Kick Attempt Good   47590.0            NaN
#
#      yardlineSide  yardlineNumber  ... penaltyJerseyNumbers penaltyYards  \
# 0             ATL              15  ...                  NaN          NaN
# 1             PHI              15  ...                  NaN          NaN
# 2             BUF              15  ...                  NaN          NaN
# 3             BUF              15  ...                  NaN          NaN
# 4             BUF              15  ...                  NaN          NaN
# ...           ...             ...  ...                  ...          ...
# 3483          SEA              15  ...                  NaN          NaN
# 3484           SF              15  ...                  NaN          NaN
# 3485           SF              15  ...                  NaN          NaN
# 3486           SF              15  ...                  NaN          NaN
# 3487          SEA              15  ...                  NaN          NaN
#
#      preSnapHomeScore  preSnapVisitorScore  passResult  \
# 0                   9                    6         NaN
# 1                  10                   12         NaN
# 2                   6                    0         NaN
# 3                  13                    0         NaN
# 4                  32                    0         NaN
# ...               ...                  ...         ...
# 3483               15                    6         NaN
# 3484               16                   12         NaN
# 3485               16                   18         NaN
# 3486               16                   25         NaN
# 3487               22                   26         NaN
#
#       absoluteYardlineNumber kicker_height  kicker_weight  kicker_position  \
# 0                         25          69.0          167.0                K
# 1                         25          69.0          203.0                K
# 2                         95          73.0          183.0                K
# 3                         95          73.0          183.0                K
# 4                         25          73.0          183.0                K
# ...                      ...           ...            ...              ...
# 3483                      95          74.0          205.0                K
# 3484                      25          70.0          190.0                K
# 3485                      25          70.0          190.0                K
# 3486                      25          70.0          190.0                K
# 3487                      95          74.0          205.0                K
#
#            kicker_name
# 0         Jake Elliott
# 1          Matt Bryant
# 2        Justin Tucker
# 3        Justin Tucker
# 4        Justin Tucker
# ...                ...
# 3483  Tristan Vizcaino
# 3484       Jason Myers
# 3485       Jason Myers
# 3486       Jason Myers
# 3487  Tristan Vizcaino
#
# [3488 rows x 22 columns]

# %% [markdown]
# Now we add in the Blockers.

# %%
ep_full = pd.merge(ep_plays, players[['nflId', 'height', 'weight','Position', 'displayName']], how = 'left',
             left_on = 'kickBlockerId', right_on = 'nflId')

# %%
eps=ep_full.rename(columns = {"height": 'blocker_height', "weight": 'blocker_weight', "Position": 'blocker_position', "displayName": 'blocker_name'})

eps=eps.drop(columns=['nflId'])

eps
# Out:
#           gameId  playId                                    playDescription  \
# 0     2018090600    2883  J.Elliott extra point is GOOD, Center-R.Lovato...
# 1     2018090600    3553  M.Bryant extra point is No Good, Hit Right Upr...
# 2     2018090900     380  J.Tucker extra point is GOOD, Center-M.Cox, Ho...
# 3     2018090900     972  J.Tucker extra point is GOOD, Center-M.Cox, Ho...
# 4     2018090900    2757  J.Tucker extra point is GOOD, Center-M.Cox, Ho...
# ...          ...     ...                                                ...
# 3483  2021010315    2813  T.Vizcaino extra point is GOOD, Center-C.Holba...
# 3484  2021010315    3074  J.Myers extra point is No Good, Wide Left, Cen...
# 3485  2021010315    3667  J.Myers extra point is GOOD, Center-T.Ott, Hol...
# 3486  2021010315    3870  J.Myers extra point is GOOD, Center-T.Ott, Hol...
# 3487  2021010315    4166  T.Vizcaino extra point is GOOD, Center-C.Holba...
#
#       quarter possessionTeam    specialTeamsResult  kickerId  kickBlockerId  \
# 0           3            PHI     Kick Attempt Good   44966.0            NaN
# 1           4            ATL  Kick Attempt No Good   27091.0            NaN
# 2           1            BAL     Kick Attempt Good   39470.0            NaN
# 3           1            BAL     Kick Attempt Good   39470.0            NaN
# 4           3            BAL     Kick Attempt Good   39470.0            NaN
# ...       ...            ...                   ...       ...            ...
# 3483        4             SF     Kick Attempt Good   47590.0            NaN
# 3484        4            SEA  Kick Attempt No Good   41175.0            NaN
# 3485        4            SEA     Kick Attempt Good   41175.0            NaN
# 3486        4            SEA     Kick Attempt Good   41175.0            NaN
# 3487        4             SF     Kick Attempt Good   47590.0            NaN
#
#      yardlineSide  yardlineNumber  ... passResult absoluteYardlineNumber  \
# 0             ATL              15  ...        NaN                     25
# 1             PHI              15  ...        NaN                     25
# 2             BUF              15  ...        NaN                     95
# 3             BUF              15  ...        NaN                     95
# 4             BUF              15  ...        NaN                     25
# ...           ...             ...  ...        ...                    ...
# 3483          SEA              15  ...        NaN                     95
# 3484           SF              15  ...        NaN                     25
# 3485           SF              15  ...        NaN                     25
# 3486           SF              15  ...        NaN                     25
# 3487          SEA              15  ...        NaN                     95
#
#      kicker_height  kicker_weight  kicker_position       kicker_name  \
# 0             69.0          167.0                K      Jake Elliott
# 1             69.0          203.0                K       Matt Bryant
# 2             73.0          183.0                K     Justin Tucker
# 3             73.0          183.0                K     Justin Tucker
# 4             73.0          183.0                K     Justin Tucker
# ...            ...            ...              ...               ...
# 3483          74.0          205.0                K  Tristan Vizcaino
# 3484          70.0          190.0                K       Jason Myers
# 3485          70.0          190.0                K       Jason Myers
# 3486          70.0          190.0                K       Jason Myers
# 3487          74.0          205.0                K  Tristan Vizcaino
#
#      blocker_height  blocker_weight  blocker_position  blocker_name
# 0               NaN             NaN               NaN           NaN
# 1               NaN             NaN               NaN           NaN
# 2               NaN             NaN               NaN           NaN
# 3               NaN             NaN               NaN           NaN
# 4               NaN             NaN               NaN           NaN
# ...             ...             ...               ...           ...
# 3483            NaN             NaN               NaN           NaN
# 3484            NaN             NaN               NaN           NaN
# 3485            NaN             NaN               NaN           NaN
# 3486            NaN             NaN               NaN           NaN
# 3487            NaN             NaN               NaN           NaN
#
# [3488 rows x 26 columns]

# %% [markdown]
# Now we use the data frame above to get some high level statistics related to extra points.
#
# Question 1: Where are the high level conversions? (by team, place kicker, yard line, time of play)

# %%
## a new data frame isolating successful conversions within Extra Points Play 
## where a successful conversion means a successful kick attempt 'Kick Attempt Good'

conv_succ = eps[(eps["specialTeamsResult"]=="Kick Attempt Good")]

# %%
## a new data frame isolating failed conversions within Extra Points Play 
## where a failed conversion means a blocked kick attempt, missed kicked attempt, 
## or nonspecial teams result

conv_fail= eps[(eps["specialTeamsResult"]=="Kick Attempt No Good")|(eps["specialTeamsResult"]=="Blocked Kick Attempt")|(eps["specialTeamsResult"]=="Non-Special Teams Result")]

# %% [markdown]
# The majority of successful extra points and failed extra point play occurs at the 15 yard line during the second quarter of the game.

# %%
conv_succ.yardlineNumber.value_counts(normalize=True)
# Out:
# 15    0.987700
# 20    0.007995
# 10    0.002153
# 25    0.001230
# 7     0.000615
# 30    0.000308
# Name: yardlineNumber, dtype: float64

# %%
conv_fail.yardlineNumber.value_counts(normalize=True)
# Out:
# 15    0.957627
# 30    0.016949
# 20    0.012712
# 25    0.008475
# 10    0.004237
# Name: yardlineNumber, dtype: float64

# %% [markdown]
# Some more details by yardage:

# %%
conv_succ.quarter.value_counts(normalize=True)
# Out:
# 2    0.308118
# 4    0.246925
# 1    0.226630
# 3    0.218327
# Name: quarter, dtype: float64

# %%
conv_fail.quarter.value_counts(normalize=True)
# Out:
# 2    0.330508
# 4    0.245763
# 1    0.241525
# 3    0.182203
# Name: quarter, dtype: float64

# %% [markdown]
# Will Lutz, Harrison Butker, Justin Tucker, and Mason Crosby led the league in total successful extra point conversations over the 2018, 2019, and 2020 seasons.

# %%
conv_succ.kicker_name.value_counts()
# Out:
# Wil Lutz                144
# Harrison Butker         143
# Justin Tucker           133
# Mason Crosby            124
# Ka'imi Fairbairn        108
# Jason Myers             106
# Greg Zuerlein           104
# Chris Boswell           101
# Matt Prater              99
# Dan Bailey               96
# Stephen Gostkowski       95
# Ryan Succop              93
# Daniel Carlson           91
# Robbie Gould             89
# Jason Sanders            88
# Cody Parkey              84
# Jake Elliott             81
# Randy Bullock            79
# Michael Badgley          79
# Brandon McManus          78
# Zane Gonzalez            77
# Aldrick Rosas            69
# Adam Vinatieri           65
# Brett Maher              65
# Dustin Hopkins           63
# Cairo Santos             61
# Joey Slye                59
# Matt Gay                 58
# Stephen Hauschka         53
# Tyler Bass               52
# Matt Bryant              47
# Graham Gano              46
# Josh Lambo               45
# Sebastian Janikowski     44
# Rodrigo Blankenship      42
# Sam Ficken               41
# Younghoe Koo             40
# Nick Folk                38
# Austin Seibert           34
# Greg Joseph              33
# Chandler Catanzaro       30
# Eddy Pineiro             25
# Chase McLaughlin         25
# Mike Nugent              24
# Sam Sloman               18
# Kai Forbath              17
# Phil Dawson              15
# Caleb Sturgis             9
# Matthew McCrane           9
# Ty Long                   8
# Giorgio Tavecchio         8
# Matthew Wright            6
# Sergio Castillo           5
# Tristan Vizcaino          2
# Brandon Wright            1
# Elliott Fry               1
# Jon Brown                 1
# Taylor Russolino          1
# Name: kicker_name, dtype: int64

# %% [markdown]
# Harrison Butker and Jason Myers led the league in total failed extra point conversions between 2018, 2019, and 2020 seasons.
#
# Note: if we look at the top 8 players with the most extra point conversion (over 100) then we can see that some of these players also had the highest number of failed extra  conversions whereas others seemed more efficient.
#
# For example, William Lutz led the league in extra point conversions and only had 2 failed extra point attempts, while Harrison Butker ranked 2nd in the league in in extra point conversions (just 1 less than Lutz) but led in failed extra point conversions over this time frame.
#
# Idea: a metric that explores efficiency of kickers

# %%
conv_fail.kicker_name.value_counts()
# Out:
# Harrison Butker         13
# Jason Myers             11
# Ryan Succop              9
# Cody Parkey              8
# Chris Boswell            8
# Ka'imi Fairbairn         8
# Dan Bailey               8
# Adam Vinatieri           8
# Austin Seibert           6
# Sam Ficken               6
# Joey Slye                6
# Mason Crosby             6
# Caleb Sturgis            6
# Stephen Gostkowski       5
# Graham Gano              5
# Matt Gay                 5
# Robbie Gould             5
# Aldrick Rosas            5
# Chandler Catanzaro       5
# Jake Elliott             5
# Zane Gonzalez            5
# Michael Badgley          4
# Brandon McManus          4
# Dustin Hopkins           4
# Daniel Carlson           4
# Josh Lambo               4
# Matt Prater              4
# Justin Tucker            4
# Younghoe Koo             4
# Greg Joseph              4
# Randy Bullock            4
# Sam Sloman               3
# Nick Folk                3
# Matt Bryant              3
# Stephen Hauschka         3
# Greg Zuerlein            3
# Sebastian Janikowski     3
# Kai Forbath              2
# Rodrigo Blankenship      2
# Eddy Pineiro             2
# Wil Lutz                 2
# Cairo Santos             2
# Mike Nugent              2
# Jason Sanders            2
# Tyler Bass               2
# Sergio Castillo          1
# Chase McLaughlin         1
# Kaare Vedvik             1
# Elliott Fry              1
# Brett Maher              1
# Taylor Russolino         1
# Name: kicker_name, dtype: int64

# %%
df1 = eps[(eps["kicker_name"] == "Wil Lutz")&(eps["specialTeamsResult"]!= "Kick Attempt Good")]

df1
# Out:
#           gameId  playId                                    playDescription  \
# 344   2018100800     347  W.Lutz extra point is No Good, Wide Right, Cen...
# 3415  2021010301    1356  W.Lutz extra point is No Good, Wide Left, Cent...
#
#       quarter possessionTeam    specialTeamsResult  kickerId  kickBlockerId  \
# 344         1             NO  Kick Attempt No Good   43689.0            NaN
# 3415        2             NO  Kick Attempt No Good   43689.0            NaN
#
#      yardlineSide  yardlineNumber  ... passResult absoluteYardlineNumber  \
# 344           WAS              15  ...        NaN                     95
# 3415          CAR              15  ...        NaN                     95
#
#      kicker_height  kicker_weight  kicker_position  kicker_name  \
# 344           71.0          184.0                K     Wil Lutz
# 3415          71.0          184.0                K     Wil Lutz
#
#      blocker_height  blocker_weight  blocker_position  blocker_name
# 344             NaN             NaN               NaN           NaN
# 3415            NaN             NaN               NaN           NaN
#
# [2 rows x 26 columns]

# %%
df2 = eps[(eps["kicker_name"] == "Harrison Butker")&(eps["specialTeamsResult"]!= "Kick Attempt Good")]

df2
# Out:
#           gameId  playId                                    playDescription  \
# 524   2018102805    1823  H.Butker extra point is No Good, Wide Left, Ce...
# 582   2018110403    2734  H.Butker extra point is No Good, Hit Right Upr...
# 753   2018111900    2567  H.Butker extra point is No Good, Wide Left, Ce...
# 881   2018120210    2278  H.Butker extra point is Blocked (A.Key), Cente...
# 1339  2019092204    1668  H.Butker extra point is No Good, Wide Left, Ce...
# 1798  2019111007    2516  H.Butker extra point is No Good, Wide Left, Ce...
# 2224  2019122214    3206  H.Butker extra point is No Good, Hit Left Upri...
# 2424  2020092012    1341  H.Butker extra point is Blocked (J.Tillery), C...
# 2502  2020092800     538  H.Butker extra point is No Good, Wide Left, Ce...
# 2575  2020100501    3262  H.Butker extra point is No Good, Wide Left, Ce...
# 2693  2020101901    1547  H.Butker extra point is No Good, Wide Right, C...
# 2740  2020102509    3612  H.Butker extra point is No Good, Hit Left Upri...
# 2868  2020110804    3323  H.Butker extra point is No Good, Hit Left Upri...
#
#       quarter possessionTeam    specialTeamsResult  kickerId  kickBlockerId  \
# 524         2             KC  Kick Attempt No Good   45046.0            NaN
# 582         3             KC  Kick Attempt No Good   45046.0            NaN
# 753         2             KC  Kick Attempt No Good   45046.0            NaN
# 881         2             KC  Blocked Kick Attempt   45046.0        46156.0
# 1339        2             KC  Kick Attempt No Good   45046.0            NaN
# 1798        3             KC  Kick Attempt No Good   45046.0            NaN
# 2224        4             KC  Kick Attempt No Good   45046.0            NaN
# 2424        2             KC  Blocked Kick Attempt   45046.0        47811.0
# 2502        1             KC  Kick Attempt No Good   45046.0            NaN
# 2575        4             KC  Kick Attempt No Good   45046.0            NaN
# 2693        2             KC  Kick Attempt No Good   45046.0            NaN
# 2740        4             KC  Kick Attempt No Good   45046.0            NaN
# 2868        4             KC  Kick Attempt No Good   45046.0            NaN
#
#      yardlineSide  yardlineNumber  ... passResult absoluteYardlineNumber  \
# 524           DEN              15  ...        NaN                     95
# 582           CLE              15  ...        NaN                     25
# 753            LA              15  ...        NaN                     25
# 881           OAK              15  ...        NaN                     25
# 1339          BAL              15  ...        NaN                     25
# 1798          TEN              15  ...        NaN                     95
# 2224          CHI              15  ...        NaN                     25
# 2424          LAC              25  ...        NaN                     85
# 2502          BAL              15  ...        NaN                     25
# 2575           NE              15  ...        NaN                     95
# 2693          BUF              15  ...        NaN                     25
# 2740          DEN              15  ...        NaN                     95
# 2868          CAR              15  ...        NaN                     25
#
#      kicker_height  kicker_weight  kicker_position      kicker_name  \
# 524           76.0          205.0                K  Harrison Butker
# 582           76.0          205.0                K  Harrison Butker
# 753           76.0          205.0                K  Harrison Butker
# 881           76.0          205.0                K  Harrison Butker
# 1339          76.0          205.0                K  Harrison Butker
# 1798          76.0          205.0                K  Harrison Butker
# 2224          76.0          205.0                K  Harrison Butker
# 2424          76.0          205.0                K  Harrison Butker
# 2502          76.0          205.0                K  Harrison Butker
# 2575          76.0          205.0                K  Harrison Butker
# 2693          76.0          205.0                K  Harrison Butker
# 2740          76.0          205.0                K  Harrison Butker
# 2868          76.0          205.0                K  Harrison Butker
#
#      blocker_height  blocker_weight  blocker_position   blocker_name
# 524             NaN             NaN               NaN            NaN
# 582             NaN             NaN               NaN            NaN
# 753             NaN             NaN               NaN            NaN
# 881            77.0           240.0                DE      Arden Key
# 1339            NaN             NaN               NaN            NaN
# 1798            NaN             NaN               NaN            NaN
# 2224            NaN             NaN               NaN            NaN
# 2424           78.0           295.0                DT  Jerry Tillery
# 2502            NaN             NaN               NaN            NaN
# 2575            NaN             NaN               NaN            NaN
# 2693            NaN             NaN               NaN            NaN
# 2740            NaN             NaN               NaN            NaN
# 2868            NaN             NaN               NaN            NaN
#
# [13 rows x 26 columns]

# %% [markdown]
# Taking a closer look at Butker's failed attempts.
#
# We can look at this manually to see the outcomes:
#
# wide left (6), wide right (1), left upright (3), right upright (1), blocked (2)
#
# This shows the Butker's kick tend to veer left when he misses. May be worth looking at the play data for his kick's versus Lutz's to understand the differencies in extra point efficiency.
#
# Note: To avoid looking at this manually in future can write code using regular expressions doing frequency count on key words "wide left" "hit right upright" "wide right" "hit left upright" "blocked"

# %%
pd.set_option("max_colwidth", None)
df2[["playDescription"]]
# Out:
#                                                                                                                                                                  playDescription
# 524                                                                                          H.Butker extra point is No Good, Wide Left, Center-J.Winchester, Holder-D.Colquitt.
# 582                                                                                  H.Butker extra point is No Good, Hit Right Upright, Center-J.Winchester, Holder-D.Colquitt.
# 753                                                                                          H.Butker extra point is No Good, Wide Left, Center-J.Winchester, Holder-D.Colquitt.
# 881                                                                                             H.Butker extra point is Blocked (A.Key), Center-J.Winchester, Holder-D.Colquitt.
# 1339                                                                                         H.Butker extra point is No Good, Wide Left, Center-J.Winchester, Holder-D.Colquitt.
# 1798                                                                                         H.Butker extra point is No Good, Wide Left, Center-J.Winchester, Holder-D.Colquitt.
# 2224                                                                                  H.Butker extra point is No Good, Hit Left Upright, Center-J.Winchester, Holder-D.Colquitt.
# 2424                                                                                        H.Butker extra point is Blocked (J.Tillery), Center-J.Winchester, Holder-T.Townsend.
# 2502                                                                                         H.Butker extra point is No Good, Wide Left, Center-J.Winchester, Holder-T.Townsend.
# 2575                                                                                         H.Butker extra point is No Good, Wide Left, Center-J.Winchester, Holder-T.Townsend.
# 2693                                                                                        H.Butker extra point is No Good, Wide Right, Center-J.Winchester, Holder-T.Townsend.
# 2740                                                                                  H.Butker extra point is No Good, Hit Left Upright, Center-J.Winchester, Holder-T.Townsend.
# 2868  H.Butker extra point is No Good, Hit Left Upright, Center-J.Winchester, Holder-T.Townsend. PENALTY on KC-A.Wylie, Unnecessary Roughness, 15 yards, enforced between downs.

# %% [markdown]
# Butker missed the majority of his extra point attempts in the 2nd and 4th quarter. The two blocked attempts both occured in the 2nd quarter.

# %%
df2.quarter.value_counts()
# Out:
# 2    6
# 4    4
# 3    2
# 1    1
# Name: quarter, dtype: int64

# %% [markdown]
# A look at which teams have a lot of extra point conversion. Immediate question: what style of play for a team leads to a high number of extra point attempts?

# %%
conv_succ.possessionTeam.value_counts()
# Out:
# NO     144
# KC     143
# BAL    133
# TB     126
# GB     124
# LA     123
# SEA    120
# IND    117
# TEN    117
# PIT    108
# HOU    108
# NE     107
# BUF    103
# LAC    103
# DAL    102
# DET     99
# ARI     99
# MIN     99
# CHI     97
# ATL     96
# SF      95
# CAR     94
# CLE     93
# MIA     88
# CIN     85
# PHI     81
# DEN     79
# NYG     79
# NYJ     67
# WAS     63
# JAX     63
# OAK     57
# LV      40
# Name: possessionTeam, dtype: int64

# %%
conv_fail.possessionTeam.value_counts()
# Out:
# CLE    17
# TB     15
# KC     14
# NYJ    11
# SEA    11
# CAR    11
# IND    10
# NE     10
# LAC    10
# MIN     9
# NYG     8
# HOU     8
# ATL     8
# SF      8
# PIT     8
# BUF     6
# TEN     6
# LA      6
# GB      6
# CHI     6
# PHI     6
# DEN     5
# JAX     5
# DET     5
# BAL     4
# WAS     4
# CIN     4
# OAK     3
# DAL     3
# ARI     3
# NO      2
# MIA     2
# LV      2
# Name: possessionTeam, dtype: int64

# %% [markdown]
# Question 2: How many times were these extra point attempts blocked? What is happening in the blocks? Can we identify good offensive and defensive line players?

# %%
## create a new data frame isolating the blocks

conv_fail_blk = conv_fail[(conv_fail["specialTeamsResult"]=="Blocked Kick Attempt")]
conv_fail_blk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 118 to 3348
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   gameId                  24 non-null     int64
#  1   playId                  24 non-null     int64
#  2   playDescription         24 non-null     object
#  3   quarter                 24 non-null     int64
#  4   possessionTeam          24 non-null     object
#  5   specialTeamsResult      24 non-null     object
#  6   kickerId                24 non-null     float64
#  7   kickBlockerId           24 non-null     float64
#  8   yardlineSide            24 non-null     object
#  9   yardlineNumber          24 non-null     int64
#  10  gameClock               24 non-null     object
#  11  penaltyCodes            2 non-null      object
#  12  penaltyJerseyNumbers    2 non-null      object
#  13  penaltyYards            2 non-null      float64
#  14  preSnapHomeScore        24 non-null     int64
#  15  preSnapVisitorScore     24 non-null     int64
#  16  passResult              0 non-null      object
#  17  absoluteYardlineNumber  24 non-null     int64
#  18  kicker_height           24 non-null     float64
#  19  kicker_weight           24 non-null     float64
#  20  kicker_position         24 non-null     object
#  21  kicker_name             24 non-null     object
#  22  blocker_height          24 non-null     float64
#  23  blocker_weight          24 non-null     float64
#  24  blocker_position        24 non-null     object
#  25  blocker_name            24 non-null     object
# dtypes: float64(7), int64(7), object(12)
# memory usage: 5.1+ KB

# %%
conv_fail_blk[["playDescription"]]
# Out:
#                                                                                                                                                                                                                        playDescription
# 118                                                                                                                                                     M.Nugent extra point is Blocked (S.Barrett), Center-T.Sieg, Holder-J.Townsend.
# 660   J.Lambo extra point is Blocked (D.Autry), Center-M.Overton, Holder-L.Cooke. DEFENSIVE TWO-POINT ATTEMPT. A.Walker recovered the blocked kick. ATTEMPT FAILS. PENALTY on IND-C.Moore, Low Block, 0 yards, enforced between downs.
# 881                                                                                                                                                   H.Butker extra point is Blocked (A.Key), Center-J.Winchester, Holder-D.Colquitt.
# 888                                                                   R.Succop extra point is Blocked (H.Anderson), Center-B.Brinkley, Holder-B.Kern. DEFENSIVE TWO-POINT ATTEMPT. T.Brooks recovered the blocked kick. ATTEMPT FAILS.
# 1274                                                                                                                                                   D.Bailey extra point is Blocked (T.Brown), Center-A.Cutting, Holder-B.Colquitt.
# 1367                                                                                                                                                   M.Gay extra point is Blocked (D.Lawrence II), Center-Z.Triner, Holder-B.Pinion.
# 1645                                                                                          S.Hauschka extra point is Blocked (D.Barnett), Center-R.Ferguson, Holder-C.Bojorquez. Ball smothered at BUF 36, no recovery after block,
# 1701                                                                     K.Fairbairn extra point is Blocked (C.Davis), Center-J.Weeks, Holder-B.Anger. DEFENSIVE TWO-POINT ATTEMPT. M.Smith recovered the blocked kick. ATTEMPT FAILS.
# 1711                                                 J.Slye extra point is Blocked (D.Cruikshank), Center-J.Jansen, Holder-M.Palardy. PENALTY on TEN-D.Bates, Lowering the Head to Initiate Contact, 15 yards, enforced between downs.
# 1726                                                                                                                                                A.Vinatieri extra point is Blocked (C.Heyward), Center-L.Rhodes, Holder-R.Sanchez.
# 1879                                                                   M.Gay extra point is Blocked (K.Sheffield), Center-Z.Triner, Holder-B.Pinion. DEFENSIVE TWO-POINT ATTEMPT. S.Neasman recovered the blocked kick. ATTEMPT FAILS.
# 1958                                                                  D.Carlson extra point is Blocked (T.Kpassagnon), Center-T.Sieg, Holder-A.Cole. DEFENSIVE TWO-POINT ATTEMPT. C.Ward recovered the blocked kick. ATTEMPT SUCCEEDS.
# 2398                                                                                                                                                 S.Sloman extra point is Blocked (H.Ridgeway), Center-J.McQuaide, Holder-J.Hekker.
# 2424                                                                                                                                              H.Butker extra point is Blocked (J.Tillery), Center-J.Winchester, Holder-T.Townsend.
# 2481                                                                 J.Slye extra point is Blocked (I.Rochell), Center-J.Jansen, Holder-J.Charlton. DEFENSIVE TWO-POINT ATTEMPT. N.Adderley recovered the blocked kick. ATTEMPT FAILS.
# 2489                                                                                                                                                      R.Succop extra point is Blocked (J.Jones), Center-Z.Triner, Holder-B.Pinion.
# 2493                                                                                                                                                G.Zuerlein extra point is Blocked (T.Flowers), Center-L.Ladouceur, Holder-C.Jones.
# 2681                                                                                                                                                   S.Sloman extra point is Blocked (D.Jordan), Center-J.McQuaide, Holder-J.Hekker.
# 2742                                                                                                                                                  R.Gould extra point is Blocked (J.Bethel), Center-T.Pepper, Holder-M.Wishnowsky.
# 2901                                                                                                                                                  C.Boswell extra point is Blocked (T.Crawford), Center-K.Canaday, Holder-J.Berry.
# 2921                                                                                                                                                        R.Succop extra point is Blocked (B.Roy), Center-Z.Triner, Holder-B.Pinion.
# 3096                                                                                                                                                  C.Santos extra point is Blocked (R.Okwara), Center-P.Scales, Holder-P.O'Donnell.
# 3242                                                                         J.Tucker extra point is Blocked (V.Taylor), Center-M.Cox, Holder-S.Koch. DEFENSIVE TWO-POINT ATTEMPT. T.Thomas recovered the blocked kick. ATTEMPT FAILS.
# 3348                                                                                                                                                 S.Ficken extra point is Blocked (S.Richardson), Center-T.Hennessy, Holder-B.Mann.

# %%
conv_fail_blk.kicker_name.value_counts()
# Out:
# Ryan Succop         3
# Sam Sloman          2
# Harrison Butker     2
# Matt Gay            2
# Joey Slye           2
# Mike Nugent         1
# Justin Tucker       1
# Cairo Santos        1
# Chris Boswell       1
# Robbie Gould        1
# Greg Zuerlein       1
# Adam Vinatieri      1
# Daniel Carlson      1
# Josh Lambo          1
# Ka'imi Fairbairn    1
# Stephen Hauschka    1
# Dan Bailey          1
# Sam Ficken          1
# Name: kicker_name, dtype: int64

# %%
conv_fail_blk_rs = conv_fail_blk[conv_fail_blk["kicker_name"]=="Ryan Succop"]
conv_fail_blk_rs
# Out:
#           gameId  playId  \
# 888   2018120211    1910
# 2489  2020092711    1788
# 2921  2020111500    2482
#
#                                                                                                                                                        playDescription  \
# 888   R.Succop extra point is Blocked (H.Anderson), Center-B.Brinkley, Holder-B.Kern. DEFENSIVE TWO-POINT ATTEMPT. T.Brooks recovered the blocked kick. ATTEMPT FAILS.
# 2489                                                                                      R.Succop extra point is Blocked (J.Jones), Center-Z.Triner, Holder-B.Pinion.
# 2921                                                                                        R.Succop extra point is Blocked (B.Roy), Center-Z.Triner, Holder-B.Pinion.
#
#       quarter possessionTeam    specialTeamsResult  kickerId  kickBlockerId  \
# 888         2            TEN  Blocked Kick Attempt   34707.0        42436.0
# 2489        2             TB  Blocked Kick Attempt   34707.0        45533.0
# 2921        3             TB  Blocked Kick Attempt   34707.0        52592.0
#
#      yardlineSide  yardlineNumber  ... passResult absoluteYardlineNumber  \
# 888           NYJ              15  ...        NaN                     95
# 2489          DEN              15  ...        NaN                     25
# 2921          CAR              15  ...        NaN                     95
#
#      kicker_height  kicker_weight  kicker_position  kicker_name  \
# 888           74.0          218.0                K  Ryan Succop
# 2489          74.0          218.0                K  Ryan Succop
# 2921          74.0          218.0                K  Ryan Succop
#
#      blocker_height  blocker_weight  blocker_position    blocker_name
# 888            78.0           301.0                DE  Henry Anderson
# 2489           72.0           231.0               ILB    Joseph Jones
# 2921           73.0           333.0                DT    Bravvion Roy
#
# [3 rows x 26 columns]

# %%
conv_fail_blk.blocker_name.value_counts()
# Out:
# Shaquil Barrett       1
# Denico Autry          1
# Vincent Taylor        1
# Romeo Okwara          1
# Bravvion Roy          1
# Tyrone Crawford       1
# Justin Bethel         1
# Dion Jordan           1
# Tre Flowers           1
# Joseph Jones          1
# Isaac Rochell         1
# Jerry Tillery         1
# Hassan Ridgeway       1
# Tanoh Kpassagnon      1
# Kendall Sheffield     1
# Cameron Heyward       1
# Dane Cruikshank       1
# Cody Davis            1
# Derek Barnett         1
# Dexter Lawrence       1
# Tony Brown            1
# Henry Anderson        1
# Arden Key             1
# Sheldon Richardson    1
# Name: blocker_name, dtype: int64

# %%
conv_fail[["playDescription"]]
# Out:
#                                                                                playDescription
# 1     M.Bryant extra point is No Good, Hit Right Upright, Center-J.Overbaugh, Holder-M.Bosher.
# 41    (Kick formation) TWO-POINT CONVERSION ATTEMPT. M.Palardy rushes left end. ATTEMPT FAILS.
# 82         Z.Gonzalez extra point is No Good, Wide Left, Center-C.Hughlett, Holder-B.Colquitt.
# 84         Z.Gonzalez extra point is No Good, Wide Left, Center-C.Hughlett, Holder-B.Colquitt.
# 87              J.Sanders extra point is No Good, Wide Right, Center-J.Denney, Holder-M.Haack.
# ...                                                                                        ...
# 3415               W.Lutz extra point is No Good, Wide Left, Center-Z.Wood, Holder-T.Morstead.
# 3432              M.Prater extra point is No Good, Wide Left, Center-D.Muhlbach, Holder-J.Fox.
# 3450               G.Gano extra point is No Good, Wide Left, Center-C.Kreiter, Holder-R.Dixon.
# 3472           K.Fairbairn extra point is No Good, Wide Right, Center-J.Weeks, Holder-B.Anger.
# 3484                J.Myers extra point is No Good, Wide Left, Center-T.Ott, Holder-M.Dickson.
#
# [236 rows x 1 columns]

# %%
#import re

# %%
#right_upright = "hit right upright"
#left_upright = "hit left upright"
#wide_left = "wide left" 
#wide_right = "wide right"
#blocked = "blocked"

#eps_fail_type1 = {'Right': [right_upright, wide_right], 
            'Left': [left_upright,wide_left],
            'Blocked': blocked}

#eps_fail_type2 = {'Options':[right_upright, left_upright, wide_right, wide_left, blocked]}

#string = "M.Bryant extra point is No Good, Hit Right Upright, Center-J.Overbaugh, Holder-M.Bosher."
#print(string.lower())
#result = re.findall(pattern,string.lower())
#print(result)

# %% [markdown]
# Revisiting the types of extra points results (which includes blocks) through the Play Description column.

# %%
conv_fail_right_upright = conv_fail.loc[conv_fail["playDescription"].str.contains("Right Upright", flags=re.IGNORECASE)]
conv_fail_left_upright = conv_fail.loc[conv_fail["playDescription"].str.contains("Left Upright", flags=re.IGNORECASE)]
conv_fail_wide_right = conv_fail.loc[conv_fail["playDescription"].str.contains("Wide Right", flags=re.IGNORECASE)]
conv_fail_wide_left = conv_fail.loc[conv_fail["playDescription"].str.contains("Wide Left", flags=re.IGNORECASE)]
conv_fail_blocked = conv_fail.loc[conv_fail["playDescription"].str.contains("Blocked", flags=re.IGNORECASE)]
conv_fail_blocked = conv_fail.loc[conv_fail["playDescription"].str.contains("Blocked", flags=re.IGNORECASE)]
conv_succ_good = conv_succ.loc[conv_succ["playDescription"].str.contains("extra point is Good", flags=re.IGNORECASE)]

# %%
conv_succ_good.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3252 entries, 0 to 3487
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   gameId                  3252 non-null   int64
#  1   playId                  3252 non-null   int64
#  2   playDescription         3252 non-null   object
#  3   quarter                 3252 non-null   int64
#  4   possessionTeam          3252 non-null   object
#  5   specialTeamsResult      3252 non-null   object
#  6   kickerId                3252 non-null   float64
#  7   kickBlockerId           0 non-null      float64
#  8   yardlineSide            3252 non-null   object
#  9   yardlineNumber          3252 non-null   int64
#  10  gameClock               3252 non-null   object
#  11  penaltyCodes            61 non-null     object
#  12  penaltyJerseyNumbers    61 non-null     object
#  13  penaltyYards            61 non-null     float64
#  14  preSnapHomeScore        3252 non-null   int64
#  15  preSnapVisitorScore     3252 non-null   int64
#  16  passResult              0 non-null      object
#  17  absoluteYardlineNumber  3252 non-null   int64
#  18  kicker_height           3252 non-null   float64
#  19  kicker_weight           3252 non-null   float64
#  20  kicker_position         3252 non-null   object
#  21  kicker_name             3252 non-null   object
#  22  blocker_height          0 non-null      float64
#  23  blocker_weight          0 non-null      float64
#  24  blocker_position        0 non-null      object
#  25  blocker_name            0 non-null      object
# dtypes: float64(7), int64(7), object(12)
# memory usage: 686.0+ KB

# %%
conv_fail_right_upright.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 1 to 3333
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   gameId                  24 non-null     int64
#  1   playId                  24 non-null     int64
#  2   playDescription         24 non-null     object
#  3   quarter                 24 non-null     int64
#  4   possessionTeam          24 non-null     object
#  5   specialTeamsResult      24 non-null     object
#  6   kickerId                24 non-null     float64
#  7   kickBlockerId           0 non-null      float64
#  8   yardlineSide            24 non-null     object
#  9   yardlineNumber          24 non-null     int64
#  10  gameClock               24 non-null     object
#  11  penaltyCodes            0 non-null      object
#  12  penaltyJerseyNumbers    0 non-null      object
#  13  penaltyYards            0 non-null      float64
#  14  preSnapHomeScore        24 non-null     int64
#  15  preSnapVisitorScore     24 non-null     int64
#  16  passResult              0 non-null      object
#  17  absoluteYardlineNumber  24 non-null     int64
#  18  kicker_height           24 non-null     float64
#  19  kicker_weight           24 non-null     float64
#  20  kicker_position         24 non-null     object
#  21  kicker_name             24 non-null     object
#  22  blocker_height          0 non-null      float64
#  23  blocker_weight          0 non-null      float64
#  24  blocker_position        0 non-null      object
#  25  blocker_name            0 non-null      object
# dtypes: float64(7), int64(7), object(12)
# memory usage: 5.1+ KB

# %%
eps[["playDescription"]]
# Out:
#                                                                                playDescription
# 0                           J.Elliott extra point is GOOD, Center-R.Lovato, Holder-C.Johnston.
# 1     M.Bryant extra point is No Good, Hit Right Upright, Center-J.Overbaugh, Holder-M.Bosher.
# 2                                   J.Tucker extra point is GOOD, Center-M.Cox, Holder-S.Koch.
# 3                                   J.Tucker extra point is GOOD, Center-M.Cox, Holder-S.Koch.
# 4                                   J.Tucker extra point is GOOD, Center-M.Cox, Holder-S.Koch.
# ...                                                                                        ...
# 3483                      T.Vizcaino extra point is GOOD, Center-C.Holba, Holder-M.Wishnowsky.
# 3484                J.Myers extra point is No Good, Wide Left, Center-T.Ott, Holder-M.Dickson.
# 3485                              J.Myers extra point is GOOD, Center-T.Ott, Holder-M.Dickson.
# 3486                              J.Myers extra point is GOOD, Center-T.Ott, Holder-M.Dickson.
# 3487                      T.Vizcaino extra point is GOOD, Center-C.Holba, Holder-M.Wishnowsky.
#
# [3488 rows x 1 columns]

# %%
conv_fail_left_upright.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 166 to 3351
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   gameId                  20 non-null     int64
#  1   playId                  20 non-null     int64
#  2   playDescription         20 non-null     object
#  3   quarter                 20 non-null     int64
#  4   possessionTeam          20 non-null     object
#  5   specialTeamsResult      20 non-null     object
#  6   kickerId                20 non-null     float64
#  7   kickBlockerId           0 non-null      float64
#  8   yardlineSide            20 non-null     object
#  9   yardlineNumber          20 non-null     int64
#  10  gameClock               20 non-null     object
#  11  penaltyCodes            1 non-null      object
#  12  penaltyJerseyNumbers    1 non-null      object
#  13  penaltyYards            1 non-null      float64
#  14  preSnapHomeScore        20 non-null     int64
#  15  preSnapVisitorScore     20 non-null     int64
#  16  passResult              0 non-null      object
#  17  absoluteYardlineNumber  20 non-null     int64
#  18  kicker_height           20 non-null     float64
#  19  kicker_weight           20 non-null     float64
#  20  kicker_position         20 non-null     object
#  21  kicker_name             20 non-null     object
#  22  blocker_height          0 non-null      float64
#  23  blocker_weight          0 non-null      float64
#  24  blocker_position        0 non-null      object
#  25  blocker_name            0 non-null      object
# dtypes: float64(7), int64(7), object(12)
# memory usage: 4.2+ KB

# %%
conv_fail_wide_left.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78 entries, 82 to 3484
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   gameId                  78 non-null     int64
#  1   playId                  78 non-null     int64
#  2   playDescription         78 non-null     object
#  3   quarter                 78 non-null     int64
#  4   possessionTeam          78 non-null     object
#  5   specialTeamsResult      78 non-null     object
#  6   kickerId                78 non-null     float64
#  7   kickBlockerId           0 non-null      float64
#  8   yardlineSide            78 non-null     object
#  9   yardlineNumber          78 non-null     int64
#  10  gameClock               78 non-null     object
#  11  penaltyCodes            0 non-null      object
#  12  penaltyJerseyNumbers    0 non-null      object
#  13  penaltyYards            0 non-null      float64
#  14  preSnapHomeScore        78 non-null     int64
#  15  preSnapVisitorScore     78 non-null     int64
#  16  passResult              0 non-null      object
#  17  absoluteYardlineNumber  78 non-null     int64
#  18  kicker_height           78 non-null     float64
#  19  kicker_weight           78 non-null     float64
#  20  kicker_position         78 non-null     object
#  21  kicker_name             78 non-null     object
#  22  blocker_height          0 non-null      float64
#  23  blocker_weight          0 non-null      float64
#  24  blocker_position        0 non-null      object
#  25  blocker_name            0 non-null      object
# dtypes: float64(7), int64(7), object(12)
# memory usage: 16.5+ KB

# %%
conv_fail_wide_right.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76 entries, 87 to 3472
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   gameId                  76 non-null     int64
#  1   playId                  76 non-null     int64
#  2   playDescription         76 non-null     object
#  3   quarter                 76 non-null     int64
#  4   possessionTeam          76 non-null     object
#  5   specialTeamsResult      76 non-null     object
#  6   kickerId                76 non-null     float64
#  7   kickBlockerId           0 non-null      float64
#  8   yardlineSide            76 non-null     object
#  9   yardlineNumber          76 non-null     int64
#  10  gameClock               76 non-null     object
#  11  penaltyCodes            0 non-null      object
#  12  penaltyJerseyNumbers    0 non-null      object
#  13  penaltyYards            0 non-null      float64
#  14  preSnapHomeScore        76 non-null     int64
#  15  preSnapVisitorScore     76 non-null     int64
#  16  passResult              0 non-null      object
#  17  absoluteYardlineNumber  76 non-null     int64
#  18  kicker_height           76 non-null     float64
#  19  kicker_weight           76 non-null     float64
#  20  kicker_position         76 non-null     object
#  21  kicker_name             76 non-null     object
#  22  blocker_height          0 non-null      float64
#  23  blocker_weight          0 non-null      float64
#  24  blocker_position        0 non-null      object
#  25  blocker_name            0 non-null      object
# dtypes: float64(7), int64(7), object(12)
# memory usage: 16.0+ KB

# %%
#import re

# %% [markdown]
# Note to self: How do we associate additional information about the type of failed extra point attempt to our 'eps' data frame? If we do this and then one hot encode it could give us something else to try and cluster around.

# %%
#right_upright = "hit right upright"
#left_upright = "hit left upright"
#wide_left = "wide left" 
#wide_right = "wide right"
#blocked = "blocked"

#eps_fail_type1 = {'Right': [right_upright, wide_right], 
            #'Left': [left_upright,wide_left],
            #'Blocked': blocked}

#eps_fail_type2 = {'Options':[right_upright, left_upright, wide_right, wide_left, blocked]}

#string = "M.Bryant extra point is No Good, Hit Right Upright, Center-J.Overbaugh, Holder-M.Bosher."
#pattern = "Hit Right Upright"
#result = re.(pattern,string)
#print(result)

#result = re.sub(r"\wHit\sRight\sUpright)(.*))
# Out:
# ['Hit Right Upright']

# %%
## regular expressions for each fail option
                
#(?i)hit\s{0,3}right\s{0,3}upright(\W|$)
#(?i)hit\s{0,3}left\s{0,3}upright(\W|$)
#(?i)wide\s{0,3}left(\W|$)
#(?i)wide\s{0,3}right(\W|$)
#(?i)blocked(\W|$)
                
## regular expression for list of possible fail options
                
#(?i)(\W|^)(hit\sright\supright|hit\sleft\supright|wide\sleft|wide\sright|blocked)(\W|$)

# %%
#conv_fail_wide_right["playDescription"] = conv_fail_wide_right["playDescription"].apply(lambda x: x.str.extract(r'(?i)wide\s{0,3}right(\W|$)', expand=False))

# %%
#conv_fail_wide_right["playDescription"]=conv_fail_wide_right["playDescription"].str.extract(r'(?i)wide\s{0,3}right(\W|$)', expand=False)

# %%
conv_fail.loc[conv_fail['playDescription'].str.contains('hit right upright', flags=re.IGNORECASE),'playDescription'] = 'hit right upright'

# %%
conv_fail.loc[conv_fail['playDescription'].str.contains('hit left upright', flags=re.IGNORECASE),'playDescription'] = 'hit left upright'

# %%
conv_fail.loc[conv_fail['playDescription'].str.contains('wide left', flags=re.IGNORECASE),'playDescription'] = 'wide left'

# %%
conv_fail.loc[conv_fail['playDescription'].str.contains('wide right', flags=re.IGNORECASE),'playDescription'] = 'wide right'

# %%
conv_fail.loc[conv_fail['playDescription'].str.contains('blocked', flags=re.IGNORECASE),'playDescription'] = 'blocked'

# %%
conv_fail.playDescription.value_counts()
# Out:
# wide left                                                                                                                                                                                  78
# wide right                                                                                                                                                                                 76
# blocked                                                                                                                                                                                    25
# Right Upright                                                                                                                                                                              24
# hit left upright                                                                                                                                                                           20
# (Kick formation) TWO-POINT CONVERSION ATTEMPT. M.Wishnowsky is sacked. ATTEMPT FAILS.                                                                                                       1
# (Kick formation) TWO-POINT CONVERSION ATTEMPT. B.Colquitt pass to K.Rudolph is incomplete. ATTEMPT FAILS.                                                                                   1
# (Kick formation) TWO-POINT CONVERSION ATTEMPT. B.Kern pass to J.Crawford is incomplete. ATTEMPT FAILS. DEFENSIVE TWO-POINT ATTEMPT. J.Bynes intercepted the try attempt. ATTEMPT FAILS.     1
# (Kick formation) TWO-POINT CONVERSION ATTEMPT. M.Wishnowsky pass is incomplete. ATTEMPT FAILS. Bad snap results in the failed attempt by 6-Wishnowsky.                                      1
# (Kick formation) TWO-POINT CONVERSION ATTEMPT. D.Colquitt pass to A.Sherman is incomplete. ATTEMPT FAILS.                                                                                   1
# (Kick formation) TWO-POINT CONVERSION ATTEMPT. R.Dixon pass to K.Smith is incomplete. ATTEMPT FAILS.                                                                                        1
# (Kick formation) TWO-POINT CONVERSION ATTEMPT. S.Martin pass to Team is incomplete. ATTEMPT FAILS. Bad snap, thrown away after recovery by holder.                                          1
# (Kick formation) TWO-POINT CONVERSION ATTEMPT. M.Darr pass is incomplete. ATTEMPT FAILS. bad snap on PAT attempt                                                                            1
# (Kick formation) TWO-POINT CONVERSION ATTEMPT. M.Palardy rushes left end. ATTEMPT FAILS.                                                                                                    1
# (Kick formation) TWO-POINT CONVERSION ATTEMPT. B.Anger rushes up the middle. ATTEMPT FAILS. DEFENSIVE TWO-POINT ATTEMPT. C.Jones recovered a fumble. ATTEMPT FAILS.                         1
# S.Janikowski extra point is No Good, Short, Center-T.Ott, Holder-M.Dickson.                                                                                                                 1
# (Kick formation) TWO-POINT CONVERSION ATTEMPT. B.Pinion rushes up the middle. ATTEMPT FAILS.                                                                                                1
# (Kick formation) TWO-POINT CONVERSION ATTEMPT. Z.Ertz rushes up the middle. ATTEMPT FAILS.                                                                                                  1
# Name: playDescription, dtype: int64

# %% [markdown]
# General Note: think its worth looking more into what is influencing the failed conversion attempts
