# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")

# %% [markdown]
# Now to read in our files and begin data cleaning and preprocessing.
#
# Note we have 7 files from the competetition hosts:
# - Game Data: games.csv, the data for each game (season, date & time, location, home and visitor teams), key variable is `gameID`.
# - PFF Scouting Data: PFFScoutingData.csv, "play-level scouting information for each game", key variables are `gameID` and `playID` (note `nflID` not included).
# - Player Data: players.csv, information for each player (height, weight, birth, college, position, name), key variable is `nflID` (Does not include `gameID` and `playID`).
# - Play Data: plays.csv, "play-level information from each game", key variables are `gameID` and `playID`.
# - Tracking Data: tracking2018.csv, tracking 2019.csv, and tracking2020.csv. Each contains "player tracking data" from the indicated season, key variables are `gameID`, `nflID`, and `playID`.

# %%
games = pd.read_csv("/Users/elizabethgrace/Documents/coding/fall-2021 copia/NFL_Big_Data_Bowl_2022/nfl-big-data-bowl-2022/games.csv")

scout = pd.read_csv("/Users/elizabethgrace/Documents/coding/fall-2021 copia/NFL_Big_Data_Bowl_2022/nfl-big-data-bowl-2022/PFFScoutingData.csv")

players = pd.read_csv("/Users/elizabethgrace/Documents/coding/fall-2021 copia/NFL_Big_Data_Bowl_2022/nfl-big-data-bowl-2022/players.csv")

play = pd.read_csv("/Users/elizabethgrace/Documents/coding/fall-2021 copia/NFL_Big_Data_Bowl_2022/nfl-big-data-bowl-2022/plays.csv")

track18 = pd.read_csv("/Users/elizabethgrace/Documents/coding/fall-2021 copia/NFL_Big_Data_Bowl_2022/nfl-big-data-bowl-2022/tracking2018.csv")
track19 = pd.read_csv("/Users/elizabethgrace/Documents/coding/fall-2021 copia/NFL_Big_Data_Bowl_2022/nfl-big-data-bowl-2022/tracking2019.csv")
track20 = pd.read_csv("/Users/elizabethgrace/Documents/coding/fall-2021 copia/NFL_Big_Data_Bowl_2022/nfl-big-data-bowl-2022/tracking2020.csv")

# %%
players
# Out:
#       nflId height  weight   birthDate          collegeName Position  \
# 0     42901    6-1     208  1992-07-25        James Madison       SS
# 1     43501    6-0     220  1994-08-11     Central Michigan       FS
# 2     43534    6-0     205  1993-06-02             Illinois       SS
# 3     43535    6-1     235  1992-12-22               Temple      MLB
# 4     44174    6-1     236  1993-02-22           Texas Tech      ILB
# ...     ...    ...     ...         ...                  ...      ...
# 2727  33216    6-3     320  06/16/1986      Central Florida        G
# 2728  33184    6-3     265  05/02/1985  Winston-Salem State       DE
# 2729  45651    5-9     198  06/16/1993                 Iowa       WR
# 2730  41284     73     230  1992-10-20                  LSU       RB
# 2731  42849   5-10     205  12/14/1992           Texas Tech       WR
#
#             displayName
# 0          Dean Marlowe
# 1         Kavon Frazier
# 2     Clayton Fejedelem
# 3      Tyler Matakevich
# 4          Sam Eguavoen
# ...                 ...
# 2727        Josh Sitton
# 2728      William Hayes
# 2729     Riley McCarron
# 2730        Jeremy Hill
# 2731    Bradley Marquez
#
# [2732 rows x 7 columns]

# %% [markdown]
# We need to standardize the height of all players. Inches will be easier to code with, so we first define a function `ft_in` to convert all heights from ft-in to inches. It also takes inches to an `int`.

# %%
def ft_in(x):
    if '-' in x:
        meas=x.split('-')
        #this will be a list ['ft','in']
        inches = int(meas[0])*12 + int(meas[1])
        return inches
    else:
        return int(x)

# %%
#test function
print(ft_in('6-0'))
print(ft_in('72'))
print(ft_in('5-10'))
# Out:
# 72
# 72
# 70

# %% [markdown]
# Now that we have checked that the function works as planned, we apply it to the `height` column of our dataframe.

# %%
players['height'] = players['height'].apply(ft_in)

# %%
players['height']
# Out:
# 0       73
# 1       72
# 2       72
# 3       73
# 4       73
#         ..
# 2727    75
# 2728    75
# 2729    69
# 2730    73
# 2731    70
# Name: height, Length: 2732, dtype: int64

# %%
players.isnull().sum()
# Out:
# nflId           0
# height          0
# weight          0
# birthDate      17
# collegeName     8
# Position        0
# displayName     0
# dtype: int64

# %% [markdown]
# `birthDate` and `collegeName` have nulls, but we're not likely using those datapoints, so we will just note that for now.

# %% [markdown]
# Now, we turn to the tracking data. We must reorient this to reflect movement in the offense direction instead of the on-field coordinates (reorient the orgin from the bottom left to top right for a change in direction).

# %% [markdown]
# [image goes here]

# %% [markdown]
# Let's make a practice dataFrame to figure this out.

# %%
df = pd.DataFrame({'x': [10,20,40,80], 'y': [10,20,40,80], 'playDirection': ["right", "left","right", "left"]})
df
# Out:
#     x   y playDirection
# 0  10  10         right
# 1  20  20          left
# 2  40  40         right
# 3  80  80          left

# %%
df.loc[df['playDirection']=='left','x'] = 120 - df.loc[df['playDirection']=='left','x']
df
# Out:
#      x   y playDirection
# 0   10  10         right
# 1  100  20          left
# 2   40  40         right
# 3   40  80          left

# %%
df.loc[df['playDirection'] == 'left', 'y'] = 160/3 - df.loc[df['playDirection']=='left','y']
df
# Out:
#      x          y playDirection
# 0   10  10.000000         right
# 1  100  33.333333          left
# 2   40  40.000000         right
# 3   40 -26.666667          left

# %% [markdown]
# Now we want to apply this to each of the actual dataFrames.

# %%
#2018 tracking data
track18.loc[track18['playDirection'] == 'left', 'x'] = 120 -track18.loc[track18['playDirection']=='left','x']
track18.loc[track18['playDirection'] == 'left', 'y'] = 160/3 -track18.loc[track18['playDirection']=='left','y']
#note that we have 160/3 for the y direction since the football field is 160ft, but our units are yards

#2019 tracking data
track19.loc[track19['playDirection'] == 'left', 'x'] = 120 -track19.loc[track19['playDirection']=='left','x']
track19.loc[track19['playDirection'] == 'left', 'y'] = 160/3 -track19.loc[track19['playDirection']=='left','y']

#2020 tracking data
track20.loc[track20['playDirection'] == 'left', 'x'] = 120 -track20.loc[track20['playDirection']=='left','x']
track20.loc[track20['playDirection'] == 'left', 'y'] = 160/3 -track20.loc[track20['playDirection']=='left','y']

print("2018:", track18)
print("2019:", track19)
print("2020:", track20)
# Out:
# 2018:                              time       x      y     s     a   dis       o  \
# 0         2018-12-30T21:25:32.200   41.32  29.45  4.36  1.33  0.43  130.42
# 1         2018-12-30T21:25:32.300   41.68  29.17  4.59  1.24  0.45  128.59
# 2         2018-12-30T21:25:32.400   42.05  28.88  4.74  0.99  0.47  124.47
# 3         2018-12-30T21:25:32.500   42.43  28.59  4.87  0.71  0.48  126.02
# 4         2018-12-30T21:25:32.600   42.84  28.31  4.96  0.79  0.50  131.71
# ...                           ...     ...    ...   ...   ...   ...     ...
# 12777346  2018-09-11T05:25:17.800  123.18  51.73  3.76  1.45  0.29     NaN
# 12777347  2018-09-11T05:25:17.900  123.40  51.89  3.19  3.02  0.28     NaN
# 12777348  2018-09-11T05:25:18.000  123.55  52.18  2.95  3.88  0.32     NaN
# 12777349  2018-09-11T05:25:18.100  123.67  52.50  3.01  4.53  0.34     NaN
# 12777350  2018-09-11T05:25:18.200  123.74  52.81  3.03  3.97  0.32     NaN
#
#              dir event    nflId    displayName  jerseyNumber position  \
# 0         128.44  None  39470.0  Justin Tucker           9.0        K
# 1         127.81  None  39470.0  Justin Tucker           9.0        K
# 2         128.15  None  39470.0  Justin Tucker           9.0        K
# 3         127.35  None  39470.0  Justin Tucker           9.0        K
# 4         124.75  None  39470.0  Justin Tucker           9.0        K
# ...          ...   ...      ...            ...           ...      ...
# 12777346     NaN  None      NaN       football           NaN      NaN
# 12777347     NaN  None      NaN       football           NaN      NaN
# 12777348     NaN  None      NaN       football           NaN      NaN
# 12777349     NaN  None      NaN       football           NaN      NaN
# 12777350     NaN  None      NaN       football           NaN      NaN
#
#               team  frameId      gameId  playId playDirection
# 0             home        1  2018123000      36         right
# 1             home        2  2018123000      36         right
# 2             home        3  2018123000      36         right
# 3             home        4  2018123000      36         right
# 4             home        5  2018123000      36         right
# ...            ...      ...         ...     ...           ...
# 12777346  football       59  2018091001    4033         right
# 12777347  football       60  2018091001    4033         right
# 12777348  football       61  2018091001    4033         right
# 12777349  football       62  2018091001    4033         right
# 12777350  football       63  2018091001    4033         right
#
# [12777351 rows x 18 columns]
# 2019:                              time       x      y     s     a   dis       o  \
# 0         2019-12-29T21:25:27.400   68.39  20.20  0.16  0.31  0.02  320.08
# 1         2019-12-29T21:25:27.500   68.38  20.21  0.16  0.28  0.02  321.66
# 2         2019-12-29T21:25:27.600   68.36  20.23  0.20  0.25  0.02  320.67
# 3         2019-12-29T21:25:27.700   68.34  20.25  0.27  0.20  0.03  303.02
# 4         2019-12-29T21:25:27.800   68.33  20.26  0.20  0.06  0.01  297.33
# ...                           ...     ...    ...   ...   ...   ...     ...
# 12170928  2019-09-10T05:02:46.600  115.84  31.60  5.96  0.48  0.80     NaN
# 12170929  2019-09-10T05:02:46.700  116.50  31.60  5.82  5.28  0.66     NaN
# 12170930  2019-09-10T05:02:46.800  117.20  31.61  5.49  7.63  0.70     NaN
# 12170931  2019-09-10T05:02:46.900  117.80  31.62  4.85  8.35  0.60     NaN
# 12170932  2019-09-10T05:02:47.000  118.33  31.63  4.15  8.09  0.53     NaN
#
#              dir event    nflId     displayName  jerseyNumber position  \
# 0         322.40  None  36060.0  Anthony Levine          41.0       DB
# 1         309.87  None  36060.0  Anthony Levine          41.0       DB
# 2         301.01  None  36060.0  Anthony Levine          41.0       DB
# 3         311.86  None  36060.0  Anthony Levine          41.0       DB
# 4         308.72  None  36060.0  Anthony Levine          41.0       DB
# ...          ...   ...      ...             ...           ...      ...
# 12170928     NaN  None      NaN        football           NaN      NaN
# 12170929     NaN  None      NaN        football           NaN      NaN
# 12170930     NaN  None      NaN        football           NaN      NaN
# 12170931     NaN  None      NaN        football           NaN      NaN
# 12170932     NaN  None      NaN        football           NaN      NaN
#
#               team  frameId      gameId  playId playDirection
# 0             home        1  2019122900      36         right
# 1             home        2  2019122900      36         right
# 2             home        3  2019122900      36         right
# 3             home        4  2019122900      36         right
# 4             home        5  2019122900      36         right
# ...            ...      ...         ...     ...           ...
# 12170928  football       58  2019090901    3554         right
# 12170929  football       59  2019090901    3554         right
# 12170930  football       60  2019090901    3554         right
# 12170931  football       61  2019090901    3554         right
# 12170932  football       62  2019090901    3554         right
#
# [12170933 rows x 18 columns]
# 2020:                              time       x          y     s     a   dis  \
# 0         2021-01-03T18:03:02.200   58.79   6.563333  0.08  0.13  0.01
# 1         2021-01-03T18:03:02.300   58.78   6.563333  0.11  0.19  0.01
# 2         2021-01-03T18:03:02.400   58.77   6.573333  0.10  0.18  0.01
# 3         2021-01-03T18:03:02.500   58.76   6.573333  0.11  0.22  0.01
# 4         2021-01-03T18:03:02.600   58.75   6.573333  0.05  0.20  0.01
# ...                           ...     ...        ...   ...   ...   ...
# 11821696  2020-09-15T05:22:39.200  117.23  32.020000  1.13  0.85  0.12
# 11821697  2020-09-15T05:22:39.300  117.31  32.100000  1.17  0.86  0.12
# 11821698  2020-09-15T05:22:39.400  117.40  32.180000  1.14  0.62  0.11
# 11821699  2020-09-15T05:22:39.500  117.48  32.250000  1.05  0.43  0.11
# 11821700  2020-09-15T05:22:39.600  117.55  32.320000  1.01  0.44  0.10
#
#                o     dir      event    nflId   displayName  jerseyNumber  \
# 0         186.21  144.73       None  42901.0  Dean Marlowe          31.0
# 1         184.87  126.09       None  42901.0  Dean Marlowe          31.0
# 2         183.38  108.95       None  42901.0  Dean Marlowe          31.0
# 3         180.24   91.57       None  42901.0  Dean Marlowe          31.0
# 4         172.44  119.91       None  42901.0  Dean Marlowe          31.0
# ...          ...     ...        ...      ...           ...           ...
# 11821696     NaN     NaN       None      NaN      football           NaN
# 11821697     NaN     NaN       None      NaN      football           NaN
# 11821698     NaN     NaN  touchback      NaN      football           NaN
# 11821699     NaN     NaN       None      NaN      football           NaN
# 11821700     NaN     NaN       None      NaN      football           NaN
#
#          position      team  frameId      gameId  playId playDirection
# 0              SS      home        1  2021010300      40          left
# 1              SS      home        2  2021010300      40          left
# 2              SS      home        3  2021010300      40          left
# 3              SS      home        4  2021010300      40          left
# 4              SS      home        5  2021010300      40          left
# ...           ...       ...      ...         ...     ...           ...
# 11821696      NaN  football       81  2020091401    4280         right
# 11821697      NaN  football       82  2020091401    4280         right
# 11821698      NaN  football       83  2020091401    4280         right
# 11821699      NaN  football       84  2020091401    4280         right
# 11821700      NaN  football       85  2020091401    4280         right
#
# [11821701 rows x 18 columns]

# %% [markdown]
# We can also divide up our play data into multiple dataframes based on `specialTeamsPlayType`.

# %%
play
# Out:
#            gameId  playId                                    playDescription  \
# 0      2018090600      37  J.Elliott kicks 65 yards from PHI 35 to end zo...
# 1      2018090600     366  (9:20) C.Johnston punts 56 yards to ATL 36, Ce...
# 2      2018090600     658  (5:03) M.Bryant 21 yard field goal is GOOD, Ce...
# 3      2018090600     677  M.Bosher kicks 64 yards from ATL 35 to PHI 1. ...
# 4      2018090600     872  (:33) C.Johnston punts 65 yards to end zone, C...
# ...           ...     ...                                                ...
# 19974  2021010315    3683  J.Myers kicks 65 yards from SEA 35 to end zone...
# 19975  2021010315    3870  J.Myers extra point is GOOD, Center-T.Ott, Hol...
# 19976  2021010315    3886  J.Myers kicks 65 yards from SEA 35 to end zone...
# 19977  2021010315    4166  T.Vizcaino extra point is GOOD, Center-C.Holba...
# 19978  2021010315    4182  M.Wishnowsky kicks onside 9 yards from SF 35 t...
#
#        quarter  down  yardsToGo possessionTeam specialTeamsPlayType  \
# 0            1     0          0            PHI              Kickoff
# 1            1     4          4            PHI                 Punt
# 2            1     4          3            ATL           Field Goal
# 3            1     0          0            ATL              Kickoff
# 4            1     4         18            PHI                 Punt
# ...        ...   ...        ...            ...                  ...
# 19974        4     0          0            SEA              Kickoff
# 19975        4     0          0            SEA          Extra Point
# 19976        4     0          0            SEA              Kickoff
# 19977        4     0          0             SF          Extra Point
# 19978        4     0          0             SF              Kickoff
#
#       specialTeamsResult  kickerId  ... penaltyCodes  penaltyJerseyNumbers  \
# 0              Touchback   44966.0  ...          NaN                   NaN
# 1                 Return   45603.0  ...         UNSd                PHI 18
# 2      Kick Attempt Good   27091.0  ...          NaN                   NaN
# 3                 Return   37267.0  ...          NaN                   NaN
# 4              Touchback   45603.0  ...          NaN                   NaN
# ...                  ...       ...  ...          ...                   ...
# 19974          Touchback   41175.0  ...          NaN                   NaN
# 19975  Kick Attempt Good   41175.0  ...          NaN                   NaN
# 19976          Touchback   41175.0  ...          NaN                   NaN
# 19977  Kick Attempt Good   47590.0  ...          NaN                   NaN
# 19978             Return   47893.0  ...          NaN                   NaN
#
#       penaltyYards  preSnapHomeScore preSnapVisitorScore passResult  \
# 0              NaN                 0                   0        NaN
# 1            -15.0                 0                   0        NaN
# 2              NaN                 0                   0        NaN
# 3              NaN                 0                   3        NaN
# 4              NaN                 0                   3        NaN
# ...            ...               ...                 ...        ...
# 19974          NaN                16                  19        NaN
# 19975          NaN                16                  25        NaN
# 19976          NaN                16                  26        NaN
# 19977          NaN                22                  26        NaN
# 19978          NaN                23                  26        NaN
#
#       kickLength  kickReturnYardage  playResult  absoluteYardlineNumber
# 0           66.0                NaN          40                      45
# 1           56.0                5.0          36                      18
# 2           21.0                NaN           0                      13
# 3           64.0               30.0          34                      75
# 4           65.0                NaN          45                      45
# ...          ...                ...         ...                     ...
# 19974       75.0                NaN          40                      75
# 19975        NaN                NaN           0                      25
# 19976       75.0                NaN          40                      75
# 19977        NaN                NaN           0                      95
# 19978        9.0                0.0           9                      45
#
# [19979 rows x 25 columns]

# %%
#kickoffs
play_kickoff = play.loc[play['specialTeamsPlayType']=='Kickoff']

#punts
play_punt=play.loc[play['specialTeamsPlayType']=='Punt']

#fieldGoals
play_fieldgoal=play.loc[play['specialTeamsPlayType']=='Field Goal']

#extraPoint
play_extrapoint = play.loc[play['specialTeamsPlayType']=='Extra Point']

# %%
play.value_counts('specialTeamsResult')
# Out:
# specialTeamsResult
# Kick Attempt Good           5470
# Return                      5207
# Touchback                   5156
# Fair Catch                  1645
# Downed                       834
# Out of Bounds                651
# Kick Attempt No Good         585
# Muffed                       214
# Non-Special Teams Result     101
# Blocked Kick Attempt          61
# Blocked Punt                  39
# Kickoff Team Recovery         16
# dtype: int64

# %%
play_kickoff.value_counts('specialTeamsResult')
# Out:
# specialTeamsResult
# Touchback                4773
# Return                   2921
# Out of Bounds              64
# Muffed                     60
# Kickoff Team Recovery      16
# Fair Catch                  5
# Downed                      4
# dtype: int64

# %%
print("Punt:", play_punt.value_counts('specialTeamsResult'))
print()
print("Field Goal:", play_fieldgoal.value_counts('specialTeamsResult'))
print()
print("Extra Point:", play_extrapoint.value_counts('specialTeamsResult'))
# Out:
# Punt: specialTeamsResult
# Return                      2286
# Fair Catch                  1640
# Downed                       829
# Out of Bounds                586
# Touchback                    383
# Muffed                       154
# Non-Special Teams Result      74
# Blocked Punt                  39
# dtype: int64
#
# Field Goal: specialTeamsResult
# Kick Attempt Good           2218
# Kick Attempt No Good         386
# Blocked Kick Attempt          37
# Non-Special Teams Result      14
# Downed                         1
# Out of Bounds                  1
# dtype: int64
#
# Extra Point: specialTeamsResult
# Kick Attempt Good           3252
# Kick Attempt No Good         199
# Blocked Kick Attempt          24
# Non-Special Teams Result      13
# dtype: int64

# %%
kick_scout=play_kickoff.merge(scout, on = ['gameId','playId'])

# %%
kick_scout
# Out:
#           gameId  playId                                    playDescription  \
# 0     2018090600      37  J.Elliott kicks 65 yards from PHI 35 to end zo...
# 1     2018090600     677  M.Bosher kicks 64 yards from ATL 35 to PHI 1. ...
# 2     2018090600    1387  J.Elliott kicks 65 yards from PHI 35 to end zo...
# 3     2018090600    1606  M.Bosher kicks 68 yards from ATL 35 to PHI -3....
# 4     2018090600    2225  M.Bosher kicks 65 yards from ATL 35 to end zon...
# ...          ...     ...                                                ...
# 7838  2021010315    2847  M.Wishnowsky kicks 65 yards from SF 35 to end ...
# 7839  2021010315    3105  J.Myers kicks 63 yards from SEA 35 to SF 2. A....
# 7840  2021010315    3683  J.Myers kicks 65 yards from SEA 35 to end zone...
# 7841  2021010315    3886  J.Myers kicks 65 yards from SEA 35 to end zone...
# 7842  2021010315    4182  M.Wishnowsky kicks onside 9 yards from SF 35 t...
#
#       quarter  down  yardsToGo possessionTeam specialTeamsPlayType  \
# 0           1     0          0            PHI              Kickoff
# 1           1     0          0            ATL              Kickoff
# 2           2     0          0            PHI              Kickoff
# 3           2     0          0            ATL              Kickoff
# 4           3     0          0            ATL              Kickoff
# ...       ...   ...        ...            ...                  ...
# 7838        4     0          0             SF              Kickoff
# 7839        4     0          0            SEA              Kickoff
# 7840        4     0          0            SEA              Kickoff
# 7841        4     0          0            SEA              Kickoff
# 7842        4     0          0             SF              Kickoff
#
#      specialTeamsResult  kickerId  ... returnDirectionActual  missedTackler  \
# 0             Touchback   44966.0  ...                   NaN            NaN
# 1                Return   37267.0  ...                     C         ATL 83
# 2             Touchback   44966.0  ...                   NaN            NaN
# 3                Return   37267.0  ...                     R            NaN
# 4             Touchback   37267.0  ...                   NaN            NaN
# ...                 ...       ...  ...                   ...            ...
# 7838          Touchback   47893.0  ...                   NaN            NaN
# 7839             Return   41175.0  ...                     R            NaN
# 7840          Touchback   41175.0  ...                   NaN            NaN
# 7841          Touchback   41175.0  ...                   NaN            NaN
# 7842             Return   47893.0  ...                   NaN            NaN
#
#      assistTackler  tackler kickoffReturnFormation gunners puntRushers  \
# 0              NaN      NaN                  8-0-2     NaN         NaN
# 1           ATL 22   ATL 27                  8-0-2     NaN         NaN
# 2              NaN      NaN                  8-0-2     NaN         NaN
# 3              NaN   ATL 36                  8-0-2     NaN         NaN
# 4              NaN      NaN                  8-0-2     NaN         NaN
# ...            ...      ...                    ...     ...         ...
# 7838           NaN      NaN                  8-0-2     NaN         NaN
# 7839           NaN   SEA 44                  8-0-2     NaN         NaN
# 7840           NaN      NaN                  8-0-2     NaN         NaN
# 7841           NaN      NaN                  8-0-2     NaN         NaN
# 7842           NaN    SF 18                  8-0-2     NaN         NaN
#
#       specialTeamsSafeties  vises  kickContactType
# 0           PHI 23; PHI 27    NaN              NaN
# 1           ATL 17; ATL 22    NaN              NaN
# 2           PHI 23; PHI 27    NaN              NaN
# 3           ATL 14; ATL 17    NaN              NaN
# 4           ATL 17; ATL 22    NaN              NaN
# ...                    ...    ...              ...
# 7838          SF 20; SF 41    NaN              NaN
# 7839        SEA 21; SEA 28    NaN              NaN
# 7840        SEA 28; SEA 99    NaN              NaN
# 7841        SEA 28; SEA 99    NaN              NaN
# 7842                 SF 43    NaN              NaN
#
# [7843 rows x 43 columns]

# %%
punt_scout=play_punt.merge(scout, on = ['gameId','playId'])

# %%
fig, axes = plt.subplots(2,1, figsize=(14,34))

axes[0].scatter(play_punt.yardsToGo, play_punt.kickLength, c="blue", s = 50, marker ="^")

axes[1].scatter(punt_scout.kickContactType.astype(str), punt_scout['playResult'].astype(str), c = "red", s = 50, marker="*")

plt.show()
